# %%
import pandas as pd
import os
os.listdir()
# Out:
# ['indicator_dataset_violin.ipynb.ipynb',
#  '.ipynb_checkpoints',
#  'indicator_dataset_water.xlsx']

# %%
df = pd.read_excel(
"indicator_dataset_water.xlsx"

)
df
# Out:
#                 Full name  \
# 0          Kayanna Warren
# 1            Lacey Hankin
# 2            Lacey Hankin
# 3            Lacey Hankin
# 4            Lacey Hankin
# 5            Lacey Hankin
# 6       Thomas Timberlake
# 7       Thomas Timberlake
# 8       Thomas Timberlake
# 9       Thomas Timberlake
# 10      Thomas Timberlake
# 11      Thomas Timberlake
# 12      Thomas Timberlake
# 13      Thomas Timberlake
# 14      Thomas Timberlake
# 15              Wes Hoyer
# 16              Wes Hoyer
# 17              Wes Hoyer
# 18  Betsy (Anne) Goodrich
# 19           Hugh Safford
# 20           Hugh Safford
# 21           Hugh Safford
# 22           Hugh Safford
# 23           Hugh Safford
#
#    What indicator(s) and dataset(s) would you use to quantify water supply in your area(s)? (Example: Indicator 1: Annual precipitation, Dataset 1: PRISM daily precipitation)  \
# 0                                                 NaN
# 1   Indicator 1: April SWE, Dataset 1: SNOTEL/Basi...
# ...

# %%
water_indicator = df['Indicator (consistent name)'].value_counts()
print(water_indicator)
# Out:
# Indicator (consistent name)
# Precipitation                                                                                                                                       4
# Snowpack                                                                                                                                            4
# April SWE                                                                                                                                           2
# Annual or seasonal precipitation                                                                                                                    2
# Climatic Water Deficit                                                                                                                              1
# Reservoir storage\n                                                                                                                                 1
# ...

# %%
water_indicator = df['Indicator (consistent name)'].value_counts().to_dict()
print(water_indicator)
# Out:
# {'Precipitation': 4, 'Snowpack': 4, 'April SWE': 2, 'Annual or seasonal precipitation': 2, 'Climatic Water Deficit': 1, 'Reservoir storage\n': 1, 'USFS Forests to Faucets dataset; https://www.fs.usda.gov/ecosystemservices/FS_Efforts/forests2faucets.shtml': 1, 'Liu et al. 2022 - role of NFS and other forests lands in providing surface drinking water supply (https://research.fs.usda.gov/treesearch/64978)': 1, 'Water Supply Importance': 1, 'Evapotranspiration (ET)': 1, 'Groundwater recharge': 1, 'Surface runoff': 1}
