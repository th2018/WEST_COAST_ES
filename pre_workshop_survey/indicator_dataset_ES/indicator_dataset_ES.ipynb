# %%
import pandas as pd
import os
# List all files
os.listdir()
# Out:
# ['indicator_dataset_ES.xlsx',
#  'idv_codes',
#  'Untitled.ipynb',
#  'indicator_dataset_CARBON.xlsx',
#  'indicator_dataset_timber.xlsx',
#  'indicator_dataset_soil_erosion.xlsx',
#  'indicator_dataset_recreation.xlsx',
#  '.ipynb_checkpoints',
#  'indicator_dataset_water.xlsx',
#  'indicator_dataset_biodiversity.xlsx']

# %%
# path to the Excel file
es_xlsx_path = "indicator_dataset_ES.xlsx"

# read all sheets into a dictionary of DataFrames

dfs= pd.read_excel(es_xlsx_path, sheet_name=None)

dfs

#print(dfs['Sheet1'])
# Out:
# {'carbon':                 Full name  \
#  0          Kayanna Warren
#  1          Kayanna Warren
#  2          Kayanna Warren
#  3          Kayanna Warren
#  4          Kayanna Warren
#  5          Kayanna Warren
#  6            Lacey Hankin
#  7            Lacey Hankin
#  8       Thomas Timberlake
#  9       Thomas Timberlake
#  10              Wes Hoyer
#  11              Wes Hoyer
#  12  Betsy (Anne) Goodrich
#  13           Hugh Safford
#
#     What indicator(s) and dataset(s) would you use to quantify carbon storage in your area(s)? (Example: Indicator 1: aboveground biomass, Dataset 1: GEDI LiDAR canopy height)\n  \
#  0   aboveground biomass; FIA+GNN. aboveground biom...
#  1   aboveground biomass; FIA+GNN. aboveground biom...
#  2   aboveground biomass; FIA+GNN. aboveground biom...
#  3   aboveground biomass; FIA+GNN. aboveground biom...
#  4   aboveground biomass; FIA+GNN. aboveground biom...
#  5   aboveground biomass; FIA+GNN. aboveground biom...
#  6   Indicator 1: Live Aboveground, Dataset 1: Tree...
#  7   Indicator 1: Live Aboveground, Dataset 1: Tree...
#  8   Indicator 1: National Forest level carbon stoc...
#  9   Indicator 1: National Forest level carbon stoc...
#  10  1: aboveground carbon, 1: treemap\n2: abovegro...
#  11  1: aboveground carbon, 1: treemap\n2: abovegro...
#  12                                                NaN
#  13  Indicator: aboveground live carbon; Dataset: N...
#
#                                              Indicator  \
#  0                                 aboveground biomass
#  1                         aboveground biomass density
#  2                          aboveground biomass change
#  3                          aboveground biomass change
#  4                       forest product carbon storage
#  5                     Disturbance/fire carbon release
#  6                                    Live Aboveground
#  7                                 aboveground biomass
#  8   National Forest level carbon stock data from C...
#  9                    Live aboveground and dead carbon
#  10                                 aboveground carbon
#  11                                aboveground biomass
#  12                                                NaN
#  13                            aboveground live carbon
#
#                                                Dataset  \
#  0                                             FIA+GNN
#  1                                             FIA+GNN
#  2                                             FIA+GNN
#  3                     change detection remote sensing
#  4                                 timber sale volumes
#  5                                                 FVS
#  6                                    Treemap Carbon_L
#  7              FRL Sierra Nevada CA Forest Assessment
#  8   Carbon Dashboard (based on estimates from FIA)...
#  9   Treemap https://apps.fs.usda.gov/lcms-viewer/t...
#  10                                            treemap
#  11                                                FIA
#  12                                                NaN
#  13                      NASA Carbon Monitoring System
#
#                  Indicator (consistent name)  \
#  0                       aboveground biomass
#  1               aboveground biomass density
#  2                aboveground biomass change
#  3                aboveground biomass change
#  4             forest product carbon storage
#  5           Disturbance/fire carbon release
#  6                          Live Aboveground
#  7                       aboveground biomass
#  8   National Forest level carbon stock data
#  9     Live aboveground and dead carbon data
#  10                       aboveground carbon
#  11                      aboveground biomass
#  12                                      NaN
#  13                  aboveground live carbon
#
#                              Dataset (consistent name)
#  0                                             FIA+GNN
#  1                                             FIA+GNN
#  2                                             FIA+GNN
#  3                     change detection remote sensing
#  4                                 timber sale volumes
#  5                                                 FVS
#  6                                    Treemap Carbon_L
#  7              FRL Sierra Nevada CA Forest Assessment
#  8   https://public.tableau.com/app/profile/usda.fo...
#  9   Treemap https://apps.fs.usda.gov/lcms-viewer/t...
#  10                                            treemap
#  11                                                FIA
#  12                                                NaN
#  13                      NASA Carbon Monitoring System  }

# %%
s_1 = "carbon"
df=dfs['carbon']
indicator_counts_df_1 = df['Indicator (consistent name)'].value_counts().reset_index()
indicator_counts_df_1.columns = ['Indicator', 'Count']
indicator_counts_df_1['Hazard'] =  s_1
indicator_counts_df_1= indicator_counts_df_1[[      "Hazard" , "Indicator",  "Count" ]]
print(indicator_counts_df_1)
# Out:
#    Hazard                                Indicator  Count
# 0  carbon                      aboveground biomass      3
# 1  carbon               aboveground biomass change      2
# 2  carbon              aboveground biomass density      1
# 3  carbon            forest product carbon storage      1
# 4  carbon          Disturbance/fire carbon release      1
# 5  carbon                         Live Aboveground      1
# 6  carbon  National Forest level carbon stock data      1
# 7  carbon    Live aboveground and dead carbon data      1
# 8  carbon                       aboveground carbon      1
# 9  carbon                  aboveground live carbon      1
