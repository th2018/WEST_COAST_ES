# %%
import pandas as pd
import os
# List all files
os.listdir()
# Out:
# ['H_indicator_counts.csv',
#  'H.xlsx',
#  'H_indicator_counts.ipynb',
#  '.ipynb_checkpoints']

# %%
# path to the Excel file
xlsx_path = "H.xlsx"

# read all sheets into a dictionary of DataFrames
dfs = pd.read_excel(xlsx_path, sheet_name=None)

dfs
# Out:
# {'wildfires':                 Full name  \
#  0          Kayanna Warren
#  1            Lacey Hankin
#  2            Lacey Hankin
#  3            Lacey Hankin
#  4       Thomas Timberlake
#  5       Thomas Timberlake
#  6       Thomas Timberlake
#  7       Thomas Timberlake
#  8       Thomas Timberlake
#  9               Wes Hoyer
#  10  Betsy (Anne) Goodrich
#  11           Hugh Safford
#  12           Hugh Safford
#  13           Hugh Safford
#
#     What indicator(s) and dataset(s) would you use to quantify wildfire hazard magnitude in your area(s)? (Example: Indicator 1: Fire Weather Index, Dataset 1: ORNL High-Resolution Fire Weather Index ...  \
#  0                                                 NaN
#  1   Indicator 1: Energy Release Component, Dataset...
#  2   Indicator 1: Energy Release Component, Dataset...
#  3   Indicator 1: Energy Release Component, Dataset...
#  4   Indicator 1: Burn probability, Dataset 1: FSIM...
#  5   Indicator 1: Burn probability, Dataset 1: FSIM...
#  6   Indicator 1: Burn probability, Dataset 1: FSIM...
#  7   Indicator 1: Burn probability, Dataset 1: FSIM...
#  8   Indicator 1: Burn probability, Dataset 1: FSIM...
#  9                                                 NaN
#  10                                                NaN
#  11  Pyrologix California-wide hazard mapping, incl...
#  12  Pyrologix California-wide hazard mapping, incl...
#  13  Pyrologix California-wide hazard mapping, incl...
#
#                                Indicator  \
#  0                                   NaN
#  1              Energy Release Component
#  2                      Burn Probability
#  3                    POD Risk Summaries
#  4                      Burn probability
#  5                          Flame length
#  6   Projected future burn probabilities
#  7                Vapor Pressure Deficit
#  8                         Soil moisture
#  9                                   NaN
#  10                                  NaN
#  11                     Burn probability
#  12         flame length and spread rate
#  13                     ember production
#
#                                                Dataset  \
#  0                                                 NaN
#  1                                     Climate Toolbox
#  2                                       RMA Dashboard
#  3                                       RMA Dashboard
#  4                                                FSIM
#  5                                             FlamMap
#  6   Robust projections of future fire probability ...
#  7                                                 NaN
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11           Pyrologix California-wide hazard mapping
#  12           Pyrologix California-wide hazard mapping
#  13           Pyrologix California-wide hazard mapping
#
#              Indicator (consistent name)  \
#  0                                   NaN
#  1              Energy Release Component
#  2                      Burn probability
#  3                    POD Risk Summaries
#  4                      Burn probability
#  5                          Flame length
#  6   Projected future burn probabilities
#  7                Vapor Pressure Deficit
#  8                         Soil moisture
#  9                                   NaN
#  10                                  NaN
#  11                     Burn probability
#  12         flame length and spread rate
#  13                     ember production
#
#                              Dataset (consistent name)
#  0                                                 NaN
#  1                                     Climate Toolbox
#  2                                       RMA Dashboard
#  3                                       RMA Dashboard
#  4                                                FSIM
#  5                                             FlamMap
#  6   Robust projections of future fire probability ...
#  7                                                 NaN
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11           Pyrologix California-wide hazard mapping
#  12           Pyrologix California-wide hazard mapping
#  13           Pyrologix California-wide hazard mapping  ,
#  'droughts':                Full name  \
#  0         Kayanna Warren
#  1           Lacey Hankin
#  2           Lacey Hankin
#  3      Thomas Timberlake
#  4      Thomas Timberlake
#  5              Wes Hoyer
#  6  Betsy (Anne) Goodrich
#  7           Hugh Safford
#
#    What indicator(s) and dataset(s) would you use to quantify drought hazard magnitude in your area(s)? (Example: Indicator 1: Vapor Pressure Deficit, Dataset 1: Daymet-derived VPD)\n  \
#  0                                                NaN
#  1  Indicator 1: VPD, Dataset 1: Climate Toolbox; ...
#  2  Indicator 1: VPD, Dataset 1: Climate Toolbox; ...
#  3  Indicator 1: Climatic Water Deficit, Dataset 1...
#  4  Indicator 1: Climatic Water Deficit, Dataset 1...
#  5                                                NaN
#  6                                                NaN
#  7                                                NaN
#
#                  Indicator                                            Dataset  \
#  0                     NaN                                                NaN
#  1                     VPD                                    Climate Toolbox
#  2       Drought Intensity                                      RMA Dashboard
#  3  Climatic Water Deficit  WADNR/TNC current and future climatic water de...
#  4  Climatic Water Deficit                                       TerraClimate
#  5                     NaN                                                NaN
#  6                     NaN                                                NaN
#  7                     NaN                                                NaN
#
#    Indicator (consistent name)  \
#  0                         NaN
#  1                         VPD
#  2           Drought Intensity
#  3      Climatic Water Deficit
#  4      Climatic Water Deficit
#  5                         NaN
#  6                         NaN
#  7                         NaN
#
#                             Dataset (consistent name)
#  0                                                NaN
#  1                                    Climate Toolbox
#  2                                      RMA Dashboard
#  3  WADNR/TNC current and future climatic water de...
#  4                                       TerraClimate
#  5                                                NaN
#  6                                                NaN
#  7                                                NaN  ,
#  'insect outbreaks':                Full name  \
#  0         Kayanna Warren
#  1         Kayanna Warren
#  2           Lacey Hankin
#  3      Thomas Timberlake
#  4      Thomas Timberlake
#  5              Wes Hoyer
#  6  Betsy (Anne) Goodrich
#  7           Hugh Safford
#
#    What indicator(s) and dataset(s) would you use to quantify insect outbreak hazard magnitude in your area(s)? (Example: Indicator 1: canopy density, Dataset 1: WADNR Forest Health Aerial Survey)\n  \
#  0  mortality severity, aerial survey and change d...
#  1  mortality severity, aerial survey and change d...
#  2  Indicator 1: tree mortality; dataset 1: Aerial...
#  3  Indicator 1: Insect-caused mortality; Dataset:...
#  4  Indicator 1: Insect-caused mortality; Dataset:...
#  5                                                NaN
#  6                                                NaN
#  7                      Forest Service aerial surveys
#
#                                            Indicator  \
#  0                                mortality severity
#  1                                mortality severity
#  2                                    tree mortality
#  3                           Insect-caused mortality
#  4  Insect-driven tree mortality models based on FIA
#  5                                               NaN
#  6                                               NaN
#  7                                               NaN
#
#                                               Dataset  \
#  0                                      aerial survey
#  1                  change detection remote sensing.
#  2                           Aerial Detection Surveys
#  3                       Aerial Detection Survey data
#  4  Anderegg et al. 2022 (https://onlinelibrary.wi...
#  5                                                NaN
#  6                                                NaN
#  7                      Forest Service aerial surveys
#
#                          Indicator (consistent name)  \
#  0                                mortality severity
#  1                                mortality severity
#  2                                    tree mortality
#  3                           Insect-caused mortality
#  4  Insect-driven tree mortality models based on FIA
#  5                                               NaN
#  6                                               NaN
#  7                                               NaN
#
#                             Dataset (consistent name)
#  0                            Aerial Detection Survey
#  1                    change detection remote sensing
#  2                            Aerial Detection Survey
#  3                            Aerial Detection Survey
#  4  Anderegg et al. 2022 (https://onlinelibrary.wi...
#  5                                                NaN
#  6                                                NaN
#  7                            Aerial Detection Survey  }

# %%
s_1 = "wildfires"
s_1_df = dfs[ s_1 ]
indicator_counts_df_1 = s_1_df['Indicator (consistent name)'].value_counts().reset_index()
indicator_counts_df_1.columns = ['Indicator', 'Count']
indicator_counts_df_1['Hazard'] =  s_1
indicator_counts_df_1= indicator_counts_df_1[[      "Hazard" , "Indicator",  "Count" ]]
print(indicator_counts_df_1)
# Out:
#       Hazard                            Indicator  Count
# 0  wildfires                     Burn probability      3
# 1  wildfires             Energy Release Component      1
# 2  wildfires                   POD Risk Summaries      1
# 3  wildfires                         Flame length      1
# 4  wildfires  Projected future burn probabilities      1
# 5  wildfires               Vapor Pressure Deficit      1
# 6  wildfires                        Soil moisture      1
# 7  wildfires         flame length and spread rate      1
# 8  wildfires                     ember production      1

# %%
s_2 = "droughts"
s_2_df = dfs[ s_2 ]
indicator_counts_df_2 = s_2_df['Indicator (consistent name)'].value_counts().reset_index()
indicator_counts_df_2.columns = ['Indicator', 'Count']
indicator_counts_df_2['Hazard'] =  s_2
indicator_counts_df_2= indicator_counts_df_2[[      "Hazard" , "Indicator",  "Count" ]]
print(indicator_counts_df_2)
# Out:
#      Hazard               Indicator  Count
# 0  droughts  Climatic Water Deficit      2
# 1  droughts                     VPD      1
# 2  droughts       Drought Intensity      1

# %%
s_3 = "insect outbreaks"
s_3_df = dfs[ s_3 ]
indicator_counts_df_3 = s_3_df['Indicator (consistent name)'].value_counts().reset_index()
indicator_counts_df_3.columns = ['Indicator', 'Count']
indicator_counts_df_3['Hazard'] =  s_3
indicator_counts_df_3= indicator_counts_df_3[[      "Hazard" , "Indicator",  "Count" ]]
print(indicator_counts_df_3)
# Out:
#              Hazard                                         Indicator  Count
# 0  insect outbreaks                                mortality severity      2
# 1  insect outbreaks                                    tree mortality      1
# 2  insect outbreaks                           Insect-caused mortality      1
# 3  insect outbreaks  Insect-driven tree mortality models based on FIA      1

# %%
H_indicator_counts = pd.concat([ indicator_counts_df_1,  indicator_counts_df_2, indicator_counts_df_3], ignore_index=True)

print(H_indicator_counts)

H_indicator_counts.to_csv("H_indicator_counts.csv")
# Out:
#               Hazard                                         Indicator  Count
# 0          wildfires                                  Burn probability      3
# 1          wildfires                          Energy Release Component      1
# 2          wildfires                                POD Risk Summaries      1
# 3          wildfires                                      Flame length      1
# 4          wildfires               Projected future burn probabilities      1
# 5          wildfires                            Vapor Pressure Deficit      1
# 6          wildfires                                     Soil moisture      1
# 7          wildfires                      flame length and spread rate      1
# 8          wildfires                                  ember production      1
# 9           droughts                            Climatic Water Deficit      2
# 10          droughts                                               VPD      1
# 11          droughts                                 Drought Intensity      1
# 12  insect outbreaks                                mortality severity      2
# 13  insect outbreaks                                    tree mortality      1
# 14  insect outbreaks                           Insect-caused mortality      1
# 15  insect outbreaks  Insect-driven tree mortality models based on FIA      1

# %%
data_counts_df_1 = s_1_df['Dataset (consistent name)'].value_counts().reset_index()
data_counts_df_1.columns = ['Dataset', 'Count']
data_counts_df_1['Hazard'] =  s_1
data_counts_df_1=  data_counts_df_1[[      "Hazard" , "Dataset",  "Count" ]]
print( data_counts_df_1 )
# Out:
#       Hazard                                            Dataset  Count
# 0  wildfires           Pyrologix California-wide hazard mapping      3
# 1  wildfires                                      RMA Dashboard      2
# 2  wildfires                                    Climate Toolbox      1
# 3  wildfires                                               FSIM      1
# 4  wildfires                                            FlamMap      1
# 5  wildfires  Robust projections of future fire probability ...      1

# %%
data_counts_df_2 = s_2_df['Dataset (consistent name)'].value_counts().reset_index()
data_counts_df_2.columns = ['Dataset', 'Count']
data_counts_df_2['Hazard'] =  s_2
data_counts_df_2=  data_counts_df_2[[      "Hazard" , "Dataset",  "Count" ]]
print( data_counts_df_2 )
# Out:
#      Hazard                                            Dataset  Count
# 0  droughts                                    Climate Toolbox      1
# 1  droughts                                      RMA Dashboard      1
# 2  droughts  WADNR/TNC current and future climatic water de...      1
# 3  droughts                                       TerraClimate      1

# %%
data_counts_df_3 = s_3_df['Dataset (consistent name)'].value_counts().reset_index()
data_counts_df_3.columns = ['Dataset', 'Count']
data_counts_df_3['Hazard'] =  s_3
data_counts_df_3=  data_counts_df_3[[      "Hazard" , "Dataset",  "Count" ]]
print( data_counts_df_3 )
# Out:
#              Hazard                                            Dataset  Count
# 0  insect outbreaks                            Aerial Detection Survey      4
# 1  insect outbreaks                    change detection remote sensing      1
# 2  insect outbreaks  Anderegg et al. 2022 (https://onlinelibrary.wi...      1

# %%
H_data_counts = pd.concat([ data_counts_df_1,  data_counts_df_2, data_counts_df_3], ignore_index=True)

print(H_data_counts)


H_data_counts.to_csv("H_data_counts.csv")
# Out:
#               Hazard                                            Dataset  Count
# 0          wildfires           Pyrologix California-wide hazard mapping      3
# 1          wildfires                                      RMA Dashboard      2
# 2          wildfires                                    Climate Toolbox      1
# 3          wildfires                                               FSIM      1
# 4          wildfires                                            FlamMap      1
# 5          wildfires  Robust projections of future fire probability ...      1
# 6           droughts                                    Climate Toolbox      1
# 7           droughts                                      RMA Dashboard      1
# 8           droughts  WADNR/TNC current and future climatic water de...      1
# 9           droughts                                       TerraClimate      1
# 10  insect outbreaks                            Aerial Detection Survey      4
# 11  insect outbreaks                    change detection remote sensing      1
# 12  insect outbreaks  Anderegg et al. 2022 (https://onlinelibrary.wi...      1
