# %%
import pandas as pd
import os
os.listdir()
# Out:
# ['other_es.ipynb',
#  '~$Are\xa0there other important forest ecosystem services in your study area(s)_.xlsx',
#  'other_es.xlsx',
#  'Are\xa0there other important forest ecosystem services in your study area(s)_.xlsx',
#  '.ipynb_checkpoints']

# %%
df = pd.read_excel(
    "other_es.xlsx",
    sheet_name="Sheet1"          # or sheet_name=0  or sheet_name="1"
)
df
# Out:
#                 Full name  \
# 0          Kayanna Warren
# 1            Lacey Hankin
# 2       Thomas Timberlake
# 3       Thomas Timberlake
# 4       Thomas Timberlake
# 5       Thomas Timberlake
# 6       Thomas Timberlake
# 7               Wes Hoyer
# 8               Wes Hoyer
# 9   Betsy (Anne) Goodrich
# 10           Hugh Safford
# 11          Robbie Andrus
# 12            Becky Estes
# 13   Laura Lazarus Lowrey
# 14            Dana Skelly
# 15    Michelle Coppoletta
# 16             Frank Koch
#
#    Are there other important forest ecosystem services in your study area(s)? If so, which ones? (also rank the importance from 1 to 5 and your expertise)  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Ecocultural stewardship involving Indigenous p...
# 3   Ecocultural stewardship involving Indigenous p...
# 4   Ecocultural stewardship involving Indigenous p...
# ...

# %%
other_es = df["Ecosystem service (consistent)"].value_counts(dropna=True)
other_es.to_csv("other_es.csv")
