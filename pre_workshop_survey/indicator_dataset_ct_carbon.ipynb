# %%
import pandas as pd
import os
os.listdir()
# Out:
# ['indicator_dataset_ct_timber.ipynb',
#  'Untitled.ipynb',
#  'indicator_dataset_CARBON.xlsx',
#  'indicator_dataset_timber.xlsx',
#  'indicator_dataset_soil_erosion.xlsx',
#  'indicator_dataset_recreation.xlsx',
#  'indicator_dataset_ct_biodiversity.ipynb',
#  'indicator_dataset_ct_water.ipynb.ipynb',
#  '.ipynb_checkpoints',
#  'indicator_dataset_water.xlsx',
#  'indicator_dataset_biodiversity.xlsx']

# %%
df = pd.read_excel(
"indicator_dataset_CARBON.xlsx"

)
df
# Out:
#                 Full name  \
# 0          Kayanna Warren
# 1          Kayanna Warren
# 2          Kayanna Warren
# 3          Kayanna Warren
# 4          Kayanna Warren
# 5          Kayanna Warren
# 6            Lacey Hankin
# 7            Lacey Hankin
# 8       Thomas Timberlake
# 9       Thomas Timberlake
# 10              Wes Hoyer
# 11              Wes Hoyer
# 12  Betsy (Anne) Goodrich
# 13           Hugh Safford
#
#    What indicator(s) and dataset(s) would you use to quantify carbon storage in your area(s)? (Example: Indicator 1: aboveground biomass, Dataset 1: GEDI LiDAR canopy height)\n  \
# 0   aboveground biomass; FIA+GNN. aboveground biom...
# 1   aboveground biomass; FIA+GNN. aboveground biom...
# 2   aboveground biomass; FIA+GNN. aboveground biom...
# 3   aboveground biomass; FIA+GNN. aboveground biom...
# 4   aboveground biomass; FIA+GNN. aboveground biom...
# 5   aboveground biomass; FIA+GNN. aboveground biom...
# 6   Indicator 1: Live Aboveground, Dataset 1: Tree...
# ...

# %%
carbon_indicator = df['Indicator (consistent name)'].value_counts()
print( carbon_indicator)
# Out:
# Indicator (consistent name)
# aboveground biomass                                                                            3
# aboveground biomass change                                                                     2
# aboveground biomass density                                                                    1
# forest product carbon storage                                                                  1
# Disturbance/fire carbon release                                                                1
# Live Aboveground                                                                               1
# National Forest level carbon stock data from Carbon Dashboard (based on estimates from FIA)    1
# Live aboveground and dead carbon data from Treemap                                             1
# aboveground carbon                                                                             1
# ...

# %%
carbon_data = df['Dataset (consistent name)'].value_counts()
print(  carbon_data)
# Out:
# Dataset (consistent name)
# FIA+GNN                                                                                                            3
# change detection remote sensing                                                                                    1
# timber sale volumes                                                                                                1
# FVS                                                                                                                1
# Treemap Carbon_L                                                                                                   1
# FRL Sierra Nevada CA Forest Assessment                                                                             1
# https://public.tableau.com/app/profile/usda.forest.service/viz/Carbon_Dashboard_Public_17056983339290/Dashboard    1
# https://apps.fs.usda.gov/lcms-viewer/treemap.html                                                                  1
# ...
