# %%
import pandas as pd
import os
os.listdir()
# Out:
# ['indicator_dataset_ct_timber.ipynb',
#  'indicator_dataset_CARBON.xlsx',
#  'indicator_dataset_timber.xlsx',
#  'indicator_dataset_ct_recreation.ipynb',
#  'indicator_dataset_soil_erosion.xlsx',
#  'indicator_dataset_recreation.xlsx',
#  'indicator_dataset_ct_carbon.ipynb',
#  'indicator_dataset_ct_biodiversity.ipynb',
#  'indicator_dataset_ct_water.ipynb.ipynb',
#  '.ipynb_checkpoints',
#  'indicator_dataset_water.xlsx',
#  'indicator_dataset_biodiversity.xlsx']

# %%
df = pd.read_excel(
"indicator_dataset_recreation.xlsx"

)
df
# Out:
#                 Full name  \
# 0          Kayanna Warren
# 1            Lacey Hankin
# 2       Thomas Timberlake
# 3       Thomas Timberlake
# 4       Thomas Timberlake
# 5               Wes Hoyer
# 6   Betsy (Anne) Goodrich
# 7   Betsy (Anne) Goodrich
# 8   Betsy (Anne) Goodrich
# 9   Betsy (Anne) Goodrich
# 10           Hugh Safford
# 11           Hugh Safford
#
#    What indicator(s) and dataset(s) would you use to quantify recreation in your area(s)? (Example: Indicator 1: visitor number/year, Dataset 1: publicly available geotagged Instagram posts)\n  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Indicator 1: Recreation infrastructure and tra...
# 3   Indicator 1: Recreation infrastructure and tra...
# 4   Indicator 1: Recreation infrastructure and tra...
# 5               1: Visitation estimates, 1: USFS NVUM
# 6   Indicator 1: Defects of standing trees in recr...
# ...

# %%
recreation_indicator = df['Indicator (consistent name)'].value_counts()
print( recreation_indicator )
# Out:
# Indicator (consistent name)
# Defects of standing trees in recreation areas    2
# mortality of trees in recreation areas           2
# visitor number per year                          2
# Recreation infrastructure and trails             1
# Social media and other data on visitor use       1
# mobile device data                               1
# Visitation estimates                             1
# Name: count, dtype: int64

# %%
recreation_data = df['Dataset (consistent name)'].value_counts()
print( recreation_data)
# Out:
# Dataset (consistent name)
# local hazard tree surveys                                                         2
# spatial data on recreation infrastructure (e.g., from USFS)                       1
# Merrill et al. 2025 paper - https://www.nature.com/articles/s41598-025-26926-w    1
# USFS NVUM                                                                         1
# knowledge that root disease is causing tree failures on site by walk-through      1
# burn severity data                                                                1
# NVUM (USFS National Visitor Use Monitoring)                                       1
# Tourism Impact Model                                                              1
# Name: count, dtype: int64
