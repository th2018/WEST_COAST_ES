# %%
import pandas as pd
import os
os.listdir()
# Out:
# ['indicator_dataset_ct_timber.ipynb',
#  'Untitled.ipynb',
#  'indicator_dataset_CARBON.xlsx',
#  'indicator_dataset_timber.xlsx',
#  'indicator_dataset_soil_erosion.xlsx',
#  'indicator_dataset_recreation.xlsx',
#  'indicator_dataset_ct_water.ipynb.ipynb',
#  '.ipynb_checkpoints',
#  'indicator_dataset_water.xlsx',
#  'indicator_dataset_biodiversity.xlsx']

# %%
df = pd.read_excel(
"indicator_dataset_biodiversity.xlsx"

)
df
# Out:
#                Full name  \
# 0         Kayanna Warren
# 1           Lacey Hankin
# 2           Lacey Hankin
# 3      Thomas Timberlake
# 4      Thomas Timberlake
# 5              Wes Hoyer
# 6              Wes Hoyer
# 7  Betsy (Anne) Goodrich
# 8           Hugh Safford
# 9           Hugh Safford
#
#   What indicator(s) and dataset(s) would you use to quantify biodiversity in your area(s)? (Example: Indicator 1: species richness, Dataset 1: TreeMap forest type)\n  \
# 0                                                NaN
# 1  Indicator 1: species richness, Dataset 1: Eveg...
# 2  Indicator 1: species richness, Dataset 1: Eveg...
# 3  Could look at vegetation types using Potential...
# 4  Could look at vegetation types using Potential...
# 5  1: Potential Vegetation, 1: USFS R6 Terrestria...
# 6  1: Potential Vegetation, 1: USFS R6 Terrestria...
# 7                                                NaN
# 8  Indicator 1: Terrestrial and aquatic diversity...
# ...

# %%
biodiversity_indicator = df['Indicator (consistent name)'].value_counts()
print(biodiversity_indicator)
# Out:
# Indicator (consistent name)
# species richness                                                                                            2
# Potential Vegetation                                                                                        1
# current forest structure                                                                                    1
# Terrestrial and aquatic diversity rankings                                                                  1
# 30 x 30 Biodiversity explorer: https://experience.arcgis.com/experience/a18f7afb32784a29a4bbb88b570bc2a3    1
# Name: count, dtype: int64

# %%
biodiversity_data = df['Dataset (consistent name)'].value_counts()
print( biodiversity_data)
# Out:
# Dataset (consistent name)
# Eveg                                                             1
# GNN                                                              1
# vegetation types using Potential Natural Vegetation maps         1
# habitat maps for certain species (e.g., Northern Spotted Owl)    1
# USFS R6 Terrestrial Ecology group data                           1
# GNN LEMMA group OSU/USFS                                         1
# Name: count, dtype: int64
