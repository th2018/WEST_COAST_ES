# %%
import pandas as pd
import os
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'indicator_dataset_timber.xlsx',
#  'indicator_dataset_ct_water.ipynb.ipynb',
#  '.ipynb_checkpoints',
#  'indicator_dataset_water.xlsx']

# %%
df = pd.read_excel(
"indicator_dataset_timber.xlsx"

)
df
# Out:
#                 Full name  \
# 0          Kayanna Warren
# 1          Kayanna Warren
# 2          Kayanna Warren
# 3            Lacey Hankin
# 4       Thomas Timberlake
# 5       Thomas Timberlake
# 6       Thomas Timberlake
# 7               Wes Hoyer
# 8               Wes Hoyer
# 9   Betsy (Anne) Goodrich
# 10  Betsy (Anne) Goodrich
# 11  Betsy (Anne) Goodrich
# 12  Betsy (Anne) Goodrich
# 13           Hugh Safford
#
#    What indicator(s) and dataset(s) would you use to quantify timber production in your area(s)? (Example: Indicator 1: Timber volume per hectare, Dataset 1: The Forest Inventory and Analysis tree vo...  \
# 0          timber volume per acre; FIA, FACTS, TIMS.
# 1          timber volume per acre; FIA, FACTS, TIMS.
# 2          timber volume per acre; FIA, FACTS, TIMS.
# 3   Indicator 1: Timber volume per hectare, Datase...
# 4   Indicator 1: Standing timber volume or biomass...
# 5   Indicator 1: Standing timber volume or biomass...
# ...

# %%
timber_indicator = df['Indicator (consistent name)'].value_counts()
print(timber_indicator)
# Out:
# Indicator (consistent name)
# timber volume per area                           4
# Standing timber volume or biomass                2
# Timber harvest                                   2
# Mortality due to root diseases                   2
# presence and severity of root diseases           2
# Timber cut and sold data for national forests    1
# Name: count, dtype: int64

# %%
timber_data = df['Dataset (consistent name)'].value_counts()
print( timber_data)
# Out:
# Dataset (consistent name)
# Forest Inventory and Analysis (FIA)                                 3
# FACTS (Forest Service Activity Tracking System)                     2
# TIMS                                                                1
# Gradient Nearest Neighbor dataset for PNW area                      1
# USFS TIM                                                            1
# stand exam data with tree level root disease information            1
# knowledge that root disease is causing mortality in the area        1
# FIA subplot information with root disease severity information      1
# Local root disease surveys (at stand/unit levels).                  1
# Name: count, dtype: int64
