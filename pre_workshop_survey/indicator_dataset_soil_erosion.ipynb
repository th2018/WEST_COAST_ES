# %%
import pandas as pd
import os
os.listdir()
# Out:
# ['indicator_dataset_ct_timber.ipynb',
#  'Untitled.ipynb',
#  'indicator_dataset_CARBON.xlsx',
#  'indicator_dataset_timber.xlsx',
#  'indicator_dataset_ct_recreation.ipynb',
#  'indicator_dataset_soil_erosion.xlsx',
#  'indicator_dataset_recreation.xlsx',
#  'indicator_dataset_ct_carbon.ipynb',
#  'indicator_dataset_ct_biodiversity.ipynb',
#  'indicator_dataset_ct_water.ipynb.ipynb',
#  '.ipynb_checkpoints',
#  'indicator_dataset_water.xlsx',
#  'indicator_dataset_biodiversity.xlsx']

# %%
df = pd.read_excel(
"indicator_dataset_soil_erosion.xlsx"

)
df
# Out:
#                Full name  \
# 0         Kayanna Warren
# 1           Lacey Hankin
# 2      Thomas Timberlake
# 3              Wes Hoyer
# 4              Wes Hoyer
# 5              Wes Hoyer
# 6  Betsy (Anne) Goodrich
# 7           Hugh Safford
#
#   What indicator(s) and dataset(s) would you use to quantify soil erosion control in your area(s)? (Example: Indicator 1: vegetation cover, Dataset 1: LANDFIRE's Existing Vegetation Type)\n  \
# 0                                                NaN
# 1                                                NaN
# 2  Indicator 1: Some sort of landslide related in...
# 3  1: current vegetaion cover/GNN, 1: LEMMA OSU/U...
# 4  1: current vegetaion cover/GNN, 1: LEMMA OSU/U...
# 5  1: current vegetaion cover/GNN, 1: LEMMA OSU/U...
# 6                                                NaN
# 7                                                NaN
#
#                      Indicator         Dataset  Indicator (consistent name)  \
# ...

# %%
erosion_indicator = df['Indicator (consistent name)'].value_counts()
print( erosion_indicator)
# Out:
# Indicator (consistent name)
# landslide related indicator    1
# current vegetaion cover/GNN    1
# soil type                      1
# slope                          1
# Name: count, dtype: int64

# %%
erosion_data = df['Dataset (consistent name)'].value_counts()
print( erosion_data)
# Out:
# Dataset (consistent name)
# LEMMA OSU/USFS    1
# SSURGO/STATSGO    1
# DEM               1
# Name: count, dtype: int64
